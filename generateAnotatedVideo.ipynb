# %% [markdown]
# # This script generates a video of general hive visualisation

# %% [markdown]
# ## Imports

# %%
import multiprocessing, cv2, os, sys
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
sys.path.append(os.path.abspath('RHCThermalPlots'))
sys.path.append(os.path.abspath('RHCImaging'))
from libvisu import *
from RHCImaging.libimage import fetchImagesPaths
from RHCImaging.VideoManagment.videolib import initVideoWriter
from RHCThermalPlots.thermalutil import generateThermalDF
from RHCThermalPlots.thermalframe import NoValidSensors
from InfluxDBInterface.libdb import download_data_DB, removeTmpOutliers
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000)  # Set a wide width for display
pd.set_option('display.colheader_justify', 'center')  # Align column headers
from dask.distributed import Client
# Start a client using all CPUs of this machine
client = Client()
client
# Out:
# INFO:distributed.http.proxy:To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# INFO:distributed.scheduler:State start
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-a9mxe50e', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-ei3gzbg5', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/scheduler-wwgkwjbt', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-2j26a9d4', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-srs62sri', purging
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:60874
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:60877'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:60879'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:60881'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:60883'
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:60889 name: 2
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:60889
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60893
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:60886 name: 0
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:60886
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60891
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:60885 name: 1
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:60885
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60890
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:60894 name: 3
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:60894
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60896
# INFO:distributed.scheduler:Receive client connection: Client-2220f206-3fe2-11f1-95e1-ee0d66769390
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60897
# <Client: 'tcp://127.0.0.1:60874' processes=4 threads=12, memory=32.00 GiB>

# %% [markdown]
# ## Configuration

# %%
# ==== GENERAL SETTINGS ====
download_data = True    # Set to True to download data from InfluxDB, False to use data stored locally
hive_nb = 2             # Hive number to process (1 or 2 for OH, 3 for BH and 0 for debugging)
ihl = None              # IHL to consider for sensory data (Put None to consider both IHLs)
t_res = "1min"          # Image time resolution. Change only if images are not taken every minute. Use frame_drop to keep only some frames, not this.
rootpath_imgs = '/Users/cyrilmonette/Library/CloudStorage/SynologyDrive-data/24.09-24.10_observation_OH/Images/'     # For images
first_dt = pd.to_datetime("241002-180000Z", format='%y%m%d-%H%M%S%z')
last_dt = pd.to_datetime("241028-110000Z", format='%y%m%d-%H%M%S%z')
frame_drop = 20         # We keep 1 frame every frame_drop frames. Put one to keep all frames.
fps = 15                # FPS of the output video

thermal_shift = 'aSensing1' # The thermal shift to apply. Use None for no shift
show_co2 = True        # Set to True to show CO2 data on the video
show_htrs = True       # Set to True to show heater data on the video

dest = "outputVideos/metabolism/"

verbose = False          # Set to True to print progress and debug messages

# ==== LOCAL DATA CONFIGURATION ====
if not download_data:
    data_path = 'data/2025-10-06_13-18_influxdb_data.csv' # Path to the local .csv or .dat file containing the CO2, htr and tmp data

# ==== DATA DOWNLOAD CONFIGURATION ====
if download_data:
    bucket = 'ObsHiveABC' # InfluxDB bucket to download data from

# %% [markdown]
# ## Main code

# %% [markdown]
# ### Image fetching

# %%
# Get the target dt (for which we need an image, data, etc.)
datetimes = pd.date_range(start=first_dt, end=last_dt, freq=t_res)
datetimes = datetimes[::frame_drop]

# Print the number of dts considered
print(f"Number of datetimes considered: {len(datetimes)}")

imgs_paths = fetchImagesPaths(rootpath_imgs, datetimes, hive_nb, images_fill_limit=10, verbose=verbose)
print(imgs_paths)
# Count the number of Nones across all rows and all columns
none_count = imgs_paths.isnull().sum().sum()
print(f"Number of missing images: {none_count} out of {len(imgs_paths) * imgs_paths.shape[1]} total images.")
# Out:
# Number of datetimes considered: 3874
# Missing images before filtering: 839 out of 15496
# [W]: There are still 782 missing images after filling with limit 10.
#                                                  h1r1                                               h1r2                                               h1r3                                               h1r4
# 2024-09-04 16:00:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...                                               None  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2024-09-04 16:20:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...                                               None  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2024-09-04 16:40:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...                                               None  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2024-09-04 17:00:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...                                               None  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2024-09-04 17:20:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...                                               None  /Users/cyrilmonette/Library/CloudStorage/Synol...
# ...                                                                      ...                                                ...                                                ...                                                ...
# 2024-10-28 09:40:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2024-10-28 10:00:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2024-10-28 10:20:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2024-10-28 10:40:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2024-10-28 11:00:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
#
# [3874 rows x 4 columns]
# Number of missing images: 782 out of 15496 total images.

# %% [markdown]
# ### Htr, co2 and tmp data fetching

# %%
if download_data:
    data_res = int(t_res[0]) * 60 * frame_drop
    filters = {'hive_num': str(hive_nb),
               'measurement': ['tmp']}
    if show_co2:
        filters['measurement'].append('co2')  # Add CO2 sensor data if needed
    if show_htrs:
        filters['measurement'].append('htr')  # Add heater data if needed
    if ihl in ['upper', 'lower']:
        filters['inhive_loc'] = ihl

    # We take a higher frequency than needed to perform filtering
    hive_data = download_data_DB(bucket, first_dt, last_dt, data_res, filters, verbose=verbose) # Restricted to our time frame and hive
    
else:
    data_path = os.path.abspath(data_path)          # Absolute path to the data
    hive_data = extractData(data_path, hive_nb, datetimes, verbose=False) # Restricted to our time frame and hive
print(hive_data.head())
# Print out the number of unique index entries (datetimes)
print(f"Number of unique datetimes in the data: {hive_data.index.nunique()}")
# Out:
#                                     _start                    _stop              _value     _field _measurement board_id geo_loc hive_num inhive_loc          mcu_uuid          phys_loc  rpi_num   serial_id    valid DeltaT actuator_instance content filling_density
# _time
# 2024-09-04 16:00:00+00:00 2024-09-04 15:40:00+00:00 2024-10-28 11:00:00+00:00  9798.392000     co2      co2       abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN         <NA>          NaN         NaN
# 2024-09-04 16:00:00+00:00 2024-09-04 15:40:00+00:00 2024-10-28 11:00:00+00:00     0.000000     pwm      htr       abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h05          NaN         NaN
# 2024-09-04 16:00:00+00:00 2024-09-04 15:40:00+00:00 2024-10-28 11:00:00+00:00    33.695312     t58      tmp       abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN         <NA>          NaN         NaN
# 2024-09-04 16:00:00+00:00 2024-09-04 15:40:00+00:00 2024-10-28 11:00:00+00:00     0.000000  status      htr       abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h05          NaN         NaN
# 2024-09-04 16:00:00+00:00 2024-09-04 15:40:00+00:00 2024-10-28 11:00:00+00:00    33.750000     t57      tmp       abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN         <NA>          NaN         NaN
# Number of unique datetimes in the data: 3867

# %% [markdown]
# ### tmp fetching

# %%
upper, lower = generateThermalDF(hive_data)   # Only tmp data, in a format that can be used by ThermalFrame

# Cleaning step of all tmp data: remove outliers
for i, df in enumerate([upper, lower]):
    for col in df.columns:
        df[col] = removeTmpOutliers(df[col], allowed_variation=2.0)

# Restrain both dataframes to the target datetimes
upper = upper[upper.index.isin(datetimes)]
lower = lower[lower.index.isin(datetimes)]
print("After restraining to target datetimes:")
print("Upper hive data shape: ", upper.shape)
print("Lower hive data shape: ", lower.shape)

# Seek the max and min values of the tmp data, in both upper and lower hives
if upper.empty:
    max_temp = np.nanmax(lower.to_numpy())
    min_temp = np.nanmin(lower.to_numpy())
elif lower.empty:
    max_temp = np.nanmax(upper.to_numpy())
    min_temp = np.nanmin(upper.to_numpy())
else:
    max_temp = np.nanmax([upper.to_numpy(), lower.to_numpy()])
    min_temp = np.nanmin([upper.to_numpy(), lower.to_numpy()])

print("Max temperature in the selected time range: ", max_temp)
print("Min temperature in the selected time range: ", min_temp)
print(lower)
# Out:
# After restraining to target datetimes:
# Upper hive data shape:  (3867, 64)
# Lower hive data shape:  (3867, 64)
# Max temperature in the selected time range:  36.5546875
# Min temperature in the selected time range:  16.3984375
#                               t00        t01        t02        t03        t04        t05        t06        t07        t08        t09        t10        t11        t12        t13        t14        t15        t16        t17        t18        t19        t20        t21        t22        t23        t24        t25        t26        t27        t28        t29        t30        t31        t32        t33        t34        t35        t36        t37        t38        t39        t40        t41        t42        t43        t44        t45        t46        t47        t48        t49        t50        t51        t52        t53        t54        t55        t56        t57        t58        t59        t60        t61        t62        t63
# _time
# 2024-09-04 16:00:00+00:00  33.085938  32.906250  32.937500  33.070312  32.789062  33.007812  33.796875  33.554688  32.734375  32.757812  32.851562  32.789062  33.554688  33.875000  32.992188  32.742188  32.875000  32.726562  32.695312  32.726562  32.757812  32.640625  32.726562  32.765625  32.578125  32.789062  33.617188  33.515625  32.632812  32.710938  32.703125  32.656250  32.906250  32.867188  32.851562  32.820312  32.750000  32.765625  32.718750  32.718750  33.398438  32.835938  32.703125  32.664062  32.671875  32.726562  32.898438  33.132812  32.617188  32.601562  32.625000  32.695312  32.625000  32.914062  33.046875  32.773438  32.734375  32.656250  32.554688  32.539062  33.023438  32.773438  32.671875  32.695312
#
# [3867 rows x 64 columns]

# %% [markdown]
# ### Metabolic data fetching

# %%
if show_co2:
    # Now we fetch the metabolic data
    co2_data =generateMetabolicDF(hive_data)
    # Restrain co2_data to the target datetimes
    co2_data = co2_data[co2_data.index.isin(datetimes)]
    print(co2_data)
else:
    co2_data = pd.DataFrame()  # Empty DataFrame if CO2 data is not to be shown
# Out:
#                               ul        ur       ll        lr
# _time
# 2024-09-04 16:00:00+00:00   9798.392     NaN   6436.479     NaN
# 2024-09-04 16:20:00+00:00   9315.661     NaN   7602.979     NaN
# 2024-09-04 16:40:00+00:00  12793.530     NaN   9874.784     NaN
# 2024-09-04 17:00:00+00:00   9560.561     NaN  10069.460     NaN
# 2024-09-04 17:20:00+00:00  10687.120     NaN  10038.200     NaN
# ...                              ...     ...        ...     ...
# 2024-10-28 08:20:00+00:00   5080.883  2195.0   4378.767  1269.0
# 2024-10-28 08:40:00+00:00   4414.603  3860.0   3480.288  4448.0
# 2024-10-28 09:00:00+00:00   3057.652   608.0   1181.047   619.0
# 2024-10-28 09:20:00+00:00   2675.709  1640.0   1638.117   755.0
# 2024-10-28 09:40:00+00:00   4389.615  3045.0   3523.097  2375.0
#
# [3867 rows x 4 columns]

# %% [markdown]
# ### htr fetching

# %%
if show_htrs:
    upper_htr = (
        hive_data
        .loc[(hive_data["inhive_loc"] == "upper") & (hive_data["_measurement"] == "htr")]
        .drop(columns=["_measurement", "_start", "_stop"])
        .copy()
    )

    lower_htr = (
        hive_data
        .loc[(hive_data["inhive_loc"] == "lower") & (hive_data["_measurement"] == "htr")]
        .drop(columns=["_measurement", "_start", "_stop"])
        .copy()
    )

    # Restrain both dataframes to the target datetimes
    upper_htr = upper_htr[upper_htr.index.isin(datetimes)]
    lower_htr = lower_htr[lower_htr.index.isin(datetimes)]
    print(upper_htr)
    print(lower_htr)
else:
    upper_htr = pd.DataFrame()  # Empty DataFrame if htr data is not to be shown
    lower_htr = pd.DataFrame()  # Empty DataFrame if htr data is not to be shown
# Out:
#                             _value    _field   board_id geo_loc hive_num inhive_loc          mcu_uuid          phys_loc  rpi_num   serial_id    valid DeltaT actuator_instance content  filling_density
# _time
# 2024-09-04 16:00:00+00:00  33.85156   avg_temp   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN          h06            NaN          NaN
# 2024-09-04 16:00:00+00:00   0.00000  is_active   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN          h06            NaN          NaN
# 2024-09-04 16:00:00+00:00  33.00000        obj   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN          h06            NaN          NaN
# 2024-09-04 16:00:00+00:00   0.00000        pwm   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN          h06            NaN          NaN
# 2024-09-04 16:00:00+00:00   0.00000     status   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN          h06            NaN          NaN
# ...                             ...        ...      ...     ...      ...        ...                        ...      ...      ...           ...    ...    ...               ...      ...             ...
# 2024-10-28 09:40:00+00:00  19.86719   avg_temp   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    0.0          h08        Unknown      Unknown
# 2024-10-28 09:40:00+00:00   0.00000        obj   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    0.0          h08        Unknown      Unknown
# 2024-10-28 09:40:00+00:00  20.33594   avg_temp   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    NaN          h05            NaN          NaN
# 2024-10-28 09:40:00+00:00   0.00000     status   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    0.0          h08        Unknown      Unknown
# 2024-10-28 09:40:00+00:00   0.00000        pwm   abc04    EPFL      1       upper    3475729523041250812900914   bass       1     /dev/ttyACM0  True    0.0          h08        Unknown      Unknown
#
# [193090 rows x 15 columns]
#                             _value    _field   board_id geo_loc hive_num inhive_loc          mcu_uuid          phys_loc  rpi_num   serial_id    valid DeltaT actuator_instance content  filling_density
# _time
# 2024-09-04 16:00:00+00:00   0.00000        pwm   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h05            NaN          NaN
# 2024-09-04 16:00:00+00:00   0.00000     status   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h05            NaN          NaN
# 2024-09-04 16:00:00+00:00  32.96094   avg_temp   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h06            NaN          NaN
# 2024-09-04 16:00:00+00:00   0.00000  is_active   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h06            NaN          NaN
# 2024-09-04 16:00:00+00:00   0.00000        obj   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h06            NaN          NaN
# ...                             ...        ...      ...     ...      ...        ...                        ...      ...      ...           ...    ...    ...               ...      ...             ...
# 2024-10-28 09:40:00+00:00   0.00000     status   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h04            NaN          NaN
# 2024-10-28 09:40:00+00:00  19.53125   avg_temp   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    0.0          h08        Unknown      Unknown
# 2024-10-28 09:40:00+00:00   0.00000        obj   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    0.0          h08        Unknown      Unknown
# 2024-10-28 09:40:00+00:00   0.00000        pwm   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    NaN          h04            NaN          NaN
# 2024-10-28 09:40:00+00:00   0.00000        pwm   abc23    EPFL      1       lower    3475735287648773847135794   bass       2     /dev/ttyACM0  True    0.0          h08        Unknown      Unknown
#
# [184190 rows x 15 columns]

# %% [markdown]
# ### Frame generation

# %%
def generate_frame(dt:pd.Timestamp, contours:list = []):
    """Generate a single annotated frame for the given datetime.

    Args:
        dt (pd.Timestamp): The datetime for which to generate the frame.
    Returns:
        np.ndarray: The generated annotated frame as an image array.
    """

    # Fetch the corresponding image paths
    _imgs_paths = imgs_paths.loc[dt].to_numpy()
    imgs_names = [str(_imgs_paths[j]).split("/")[-1][:-4] for j in range(len(_imgs_paths))]
    # Read the images using cv2
    current_imgs = []
    for _img_path in _imgs_paths:
        if _img_path is not None:
            img = cv2.imread(_img_path, cv2.IMREAD_GRAYSCALE)
            current_imgs.append(img)
        else:
            current_imgs.append(None)
    
    # Thermal data
    try:
        upper_tf = ThermalFrame(upper.loc[dt].to_numpy())
    except (NoValidSensors, KeyError):
        upper_tf = None

    try:
        lower_tf = ThermalFrame(lower.loc[dt].to_numpy())
    except (NoValidSensors, KeyError):
        lower_tf = None

    # Metabolic data
    if dt in co2_data.index:
        metabolic_df = co2_data.loc[dt]
    else:
        metabolic_df = None

    # Lower heater
    if dt in lower_htr.index:
        lower_htr_row = lower_htr.loc[dt]
    else:
        lower_htr_row = None

    # Upper heater
    if dt in upper_htr.index:
        upper_htr_row = upper_htr.loc[dt]
    else:
        upper_htr_row = None
    
    hs = Hive(dt, current_imgs, False, imgs_names, upper_tf, lower_tf, metabolic_df, upper_htr_row, lower_htr_row, hive_nb=hive_nb)
    if thermal_shift is not None:
        from libvisu import exp_thermal_shifts
        hs.setThermalShifts(exp_thermal_shifts[thermal_shift][hive_nb])
    snapshot = hs.snapshot(v_max=max_temp, v_min=min_temp, contours=contours, annotate_contours=True, thermal_transparency=0.4, check_validity=True, annotate_names=False, use_cet_time=False)

    return snapshot

# %% [markdown]
# ### Plotting

# %%
frame = 1000 # Frame idx within datetimes
dt = datetimes[frame]
_imgs_paths = imgs_paths.loc[dt].to_numpy()
contours = list(range(12, 38, 2))
snapshot = generate_frame(dt, contours=contours)
# For a random time frame, generate the image of the hive and the thermal plot side by side with matplotlib
# This is just to check that everything is working fine
plt.figure(figsize=(18, 12))
plt.imshow(snapshot)
plt.axis('off') 
plt.show()

# %% [markdown]
# ### Automation

# %%
snapshot_0 = generate_frame(datetimes[0], contours=contours)
filename=f"hive{hive_nb}_{first_dt.strftime('%y%m%d-%H%M%Z')}_{last_dt.strftime('%y%m%d-%H%M%Z')}"
# If file exists, add a number to the name
counter = 1
while os.path.isfile(dest+filename+".mp4"):
    print(f"File {filename} already exists. Adding a counter to the filename.")
    if counter > 1:
        # Remove the previous counter
        filename = filename[:-(len(str(counter-1))+1)]
    filename = f"{filename}_{counter}"
    counter += 1
    
video = initVideoWriter(dest=dest, shape=snapshot_0.shape, name=filename, fps=fps) # RGB video
print("Writing video with dimensions: ", snapshot_0.shape)

for dt in tqdm(datetimes, desc="Generating video frames"):
    snapshot = generate_frame(dt, contours=contours)
    # Convert from RGB to BGR
    snapshot = cv2.cvtColor(snapshot, cv2.COLOR_RGB2BGR)
    video.write(snapshot)

# Release the VideoWriter object
video.release()
print("Video written successfully.")

# Cleanup step to release resources
multiprocessing.active_children()
# Out:
# Writing video with dimensions:  (2160, 3840, 3)
# Generating video frames:   6%|▌         | 214/3874 [06:48<1:52:51,  1.85s/it] ERROR:tornado.application:Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 99 memory: 2484 MB fds: 184>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/imaging/lib/python3.11/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/imaging/lib/python3.11/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/imaging/lib/python3.11/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
# Generating video frames: 100%|██████████| 3874/3874 [3:17:46<00:00,  3.06s/it]
# Video written successfully.
# [<SpawnProcess name='Dask Worker process (from Nanny)' pid=30429 parent=30412 started daemon>,
#  <SpawnProcess name='Dask Worker process (from Nanny)' pid=30430 parent=30412 started daemon>,
#  <SpawnProcess name='Dask Worker process (from Nanny)' pid=30431 parent=30412 started daemon>,
#  <SpawnProcess name='Dask Worker process (from Nanny)' pid=30428 parent=30412 started daemon>]
