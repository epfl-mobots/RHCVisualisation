# %% [markdown]
# # This script generates a video of general hive visualisation

# %% [markdown]
# ## Imports

# %%
import multiprocessing, cv2, os, sys
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
sys.path.append(os.path.abspath('ABCThermalPlots'))
sys.path.append(os.path.abspath('ABCImaging'))
from libvisu import *
from ABCImaging.libimage import fetchImagesPaths
from ABCImaging.VideoManagment.videolib import initVideoWriter
from InfluxDBInterface.libdb import download_data_DB, removeTmpOutliers
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000)  # Set a wide width for display
pd.set_option('display.colheader_justify', 'center')  # Align column headers
from dask.distributed import Client
# Start a client using all CPUs of this machine
client = Client()
client
# Out:
# INFO:distributed.http.proxy:To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# INFO:distributed.scheduler:State start
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-rhmv3c59', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/scheduler-3lx5qby7', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-rojp25ij', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-ctji99yf', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-se0l4l6b', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-11zplzhz', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-n9l04ytk', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-9p3vf83q', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/scheduler-l9ht0jdl', purging
# INFO:distributed.diskutils:Found stale lock file and directory '/var/folders/w2/m4mvm5pj37107n10n7fs6sd80000gr/T/dask-scratch-space/worker-gplc6_r1', purging
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:64083
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:64086'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:64088'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:64090'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:64092'
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:64094 name: 1
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:64094
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:64104
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:64095 name: 3
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:64095
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:64103
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:64097 name: 0
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:64097
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:64105
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:64096 name: 2
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:64096
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:64102
# INFO:distributed.scheduler:Receive client connection: Client-0c589bce-01e2-11f1-a449-ee0d6676938e
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:64106
# <Client: 'tcp://127.0.0.1:64083' processes=4 threads=12, memory=32.00 GiB>
# ERROR:tornado.application:Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 105 memory: 1601 MB fds: 186>>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory

# %% [markdown]
# ## Configuration

# %%
# ==== GENERAL SETTINGS ====
download_data = True    # Set to True to download data from InfluxDB, False to use data stored locally
hive_nb = 1             # Hive number to process (1 or 2 for OH, 3 for BH and 0 for debugging)
ihl = None              # IHL to consider for sensory data (Put None to consider both IHLs)
t_res = "5min"          # Image time resolution. Change only if images are not taken every minute. Use frame_drop to keep only some frames, not this.
rootpath_imgs = '/Users/cyrilmonette/Library/CloudStorage/SynologyDrive-data/25.07-25.10_aSensing_OH/Images/'     # For images
first_dt = pd.to_datetime("250723-210000Z", format='%y%m%d-%H%M%S%z')
last_dt = pd.to_datetime("250726-210000Z", format='%y%m%d-%H%M%S%z')
frame_drop = 1          # We keep 1 frame every frame_drop frames. Put one to keep all frames.
fps = 15                # FPS of the output video

thermal_shift = 'aSensing2' # The thermal shift to apply. Use None for no shift
show_co2 = False        # Set to True to show CO2 data on the video
show_htrs = True       # Set to True to show heater data on the video

dest = "outputVideos/"

verbose = True          # Set to True to print progress messages

# ==== LOCAL DATA CONFIGURATION ====
if not download_data:
    data_path = 'data/2025-10-06_13-18_influxdb_data.csv' # Path to the local .csv or .dat file containing the CO2, htr and tmp data

# ==== DATA DOWNLOAD CONFIGURATION ====
if download_data:
    bucket = 'a_sensing' # InfluxDB bucket to download data from

# %% [markdown]
# ## Main code

# %% [markdown]
# ### Image fetching

# %%
# Get the target dt (for which we need an image, data, etc.)
datetimes = pd.date_range(start=first_dt, end=last_dt, freq=t_res)
datetimes = datetimes[::frame_drop]

# Print the number of dts considered
print(f"Number of datetimes considered: {len(datetimes)}")

imgs_paths = fetchImagesPaths(rootpath_imgs, datetimes, hive_nb)
print(imgs_paths)
# Count the number of Nones across all rows and all columns
none_count = imgs_paths.isnull().sum().sum()
print(f"Number of missing images: {none_count} out of {len(imgs_paths) * imgs_paths.shape[1]} total images.")
# Out:
# Number of datetimes considered: 865
#                                                  h1r1                                               h1r2                                               h1r3                                               h1r4
# 2025-07-23 19:00:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2025-07-23 19:05:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2025-07-23 19:10:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2025-07-23 19:15:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2025-07-23 19:20:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# ...                                                                      ...                                                ...                                                ...                                                ...
# 2025-07-26 18:40:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2025-07-26 18:45:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2025-07-26 18:50:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2025-07-26 18:55:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
# 2025-07-26 19:00:00+00:00  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...  /Users/cyrilmonette/Library/CloudStorage/Synol...
#
# [865 rows x 4 columns]
# Number of missing images: 0 out of 3460 total images.

# %% [markdown]
# ### Htr, co2 and tmp data fetching

# %%
if download_data:
    data_res = int(t_res[0]) * 60 * frame_drop
    filters = {'hive_num': str(hive_nb),
               'measurement': ['tmp']}
    if show_co2:
        filters['measurement'].append('co2')  # Add CO2 sensor data if needed
    if show_htrs:
        filters['measurement'].append('htr')  # Add heater data if needed
    if ihl in ['upper', 'lower']:
        filters['inhive_loc'] = ihl

    # We take a higher frequency than needed to perform filtering
    hive_data = download_data_DB(bucket, first_dt, last_dt, data_res, filters, verbose=verbose) # Restricted to our time frame and hive
    
else:
    data_path = os.path.abspath(data_path)          # Absolute path to the data
    hive_data = extractData(data_path, hive_nb, datetimes, verbose=False) # Restricted to our time frame and hive
print(hive_data.head())
# Print out the number of unique index entries (datetimes)
print(f"Number of unique datetimes in the data: {hive_data.index.nunique()}")
# Out:
# Executing query:
#
#     from(bucket: "a_sensing")
#       |> range(start: 2025-07-23T18:55:00Z, stop: 2025-07-26T19:00:00Z)
#       |> filter(fn: (r) => r["_measurement"] == "tmp" or r["_measurement"] == "htr")
#       |> filter(fn: (r) => r["hive_num"] == "1")
#       |> aggregateWindow(every: 300s, fn: last, createEmpty: false)
#       |> yield(name: "last")
#
#                                     _start                    _stop             _value   DeltaT   _field  _measurement actuator_instance board_id content  filling_density geo_loc hive_num inhive_loc          mcu_uuid          phys_loc  rpi_num   serial_id    valid
# _time
# 2025-07-23 19:00:00+00:00 2025-07-23 18:55:00+00:00 2025-07-26 19:00:00+00:00  31.710940   0.0   avg_temp      htr             h00         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00 2025-07-23 18:55:00+00:00 2025-07-26 19:00:00+00:00  32.507812   NaN        t53      tmp            <NA>         abc02       NaN          NaN      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00 2025-07-23 18:55:00+00:00 2025-07-26 19:00:00+00:00  33.210938   NaN        t54      tmp            <NA>         abc02       NaN          NaN      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00 2025-07-23 18:55:00+00:00 2025-07-26 19:00:00+00:00  33.945312   NaN        t55      tmp            <NA>         abc02       NaN          NaN      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00 2025-07-23 18:55:00+00:00 2025-07-26 19:00:00+00:00  31.617188   NaN        t56      tmp            <NA>         abc02       NaN          NaN      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# Number of unique datetimes in the data: 865

# %% [markdown]
# ### tmp fetching

# %%
upper, lower = generateThermalDF(hive_data)   # Only tmp data, in a format that can be used by ThermalFrame

# Cleaning step of all tmp data: remove outliers
for i, df in enumerate([upper, lower]):
    for col in tqdm(df.columns, desc=f"Removing tmp outliers in df {i}"):
        df[col] = removeTmpOutliers(df[col], allowed_variation=2.0)

# Restrain both dataframes to the target datetimes
upper = upper[upper.index.isin(datetimes)]
lower = lower[lower.index.isin(datetimes)]
print("After restraining to target datetimes:")
print("Upper hive data shape: ", upper.shape)
print("Lower hive data shape: ", lower.shape)

# Seek the max and min values of the tmp data, in both upper and lower hives
if upper.empty:
    max_temp = np.nanmax(lower.to_numpy())
    min_temp = np.nanmin(lower.to_numpy())
elif lower.empty:
    max_temp = np.nanmax(upper.to_numpy())
    min_temp = np.nanmin(upper.to_numpy())
else:
    max_temp = np.nanmax([upper.to_numpy(), lower.to_numpy()])
    min_temp = np.nanmin([upper.to_numpy(), lower.to_numpy()])

print("Max temperature in the selected time range: ", max_temp)
print("Min temperature in the selected time range: ", min_temp)
print(lower)
# Out:
# Removing tmp outliers in df 0: 100%|██████████| 64/64 [00:00<00:00, 2122.51it/s]
# Removing tmp outliers in df 1: 100%|██████████| 64/64 [00:00<00:00, 2208.11it/s]
# After restraining to target datetimes:
# Upper hive data shape:  (865, 64)
# Lower hive data shape:  (865, 64)
# Max temperature in the selected time range:  36.0390625
# Min temperature in the selected time range:  22.921875
#                               t00        t01        t02        t03        t04        t05        t06        t07        t08        t09        t10        t11        t12        t13        t14        t15        t16        t17        t18        t19        t20        t21        t22        t23        t24        t25        t26        t27        t28        t29        t30        t31        t32        t33        t34        t35        t36        t37        t38        t39        t40        t41        t42        t43        t44        t45        t46        t47        t48        t49        t50        t51        t52        t53        t54        t55        t56        t57        t58        t59        t60        t61        t62        t63
# _time
# 2025-07-23 19:00:00+00:00  32.039062  31.257812  30.687500  30.445312  31.210938  31.945312  32.718750  32.351562  30.765625  30.359375  30.351562  30.593750  32.140625  32.515625  31.585938  31.179688  31.421875  31.132812  30.851562  30.476562  31.835938  31.421875  31.039062  30.640625  31.937500  32.429688  32.843750  32.421875  31.695312  31.046875  30.851562  31.351562  32.476562  32.492188  32.406250  32.507812  32.289062  32.421875  32.281250  32.218750  33.007812  33.234375  32.765625  32.523438  32.218750  33.593750  34.015625  33.046875  33.671875  32.375000  31.570312  31.289062  33.234375  32.507812  33.210938  33.945312  31.617188  31.757812  32.335938  33.132812  32.000000  32.273438  32.265625  31.890625
# 2025-07-23 19:05:00+00:00  31.515625  30.992188  30.609375  30.351562  30.960938  31.523438  32.343750  32.000000  31.437500  31.023438  30.250000  30.507812  32.085938  32.445312  31.507812  31.242188  31.351562  31.390625  31.460938  31.179688  31.742188  31.398438  31.109375  30.648438  31.812500  32.375000  32.781250  32.359375  31.585938  30.937500  30.703125  31.210938  32.421875  32.437500  32.351562  32.453125  32.218750  32.367188  32.210938  32.140625  32.953125  33.257812  32.734375  32.460938  32.164062  33.617188  34.046875  33.023438  33.625000  32.296875  31.468750  31.195312  33.179688  32.468750  33.226562  33.921875  31.453125  31.601562  32.179688  33.007812  31.937500  32.226562  32.171875  31.726562
        .drop(columns=["_measurement", "_start", "_stop"])
        .copy()
    )

    lower_htr = (
        hive_data
        .loc[(hive_data["inhive_loc"] == "lower") & (hive_data["_measurement"] == "htr")]
        .drop(columns=["_measurement", "_start", "_stop"])
        .copy()
    )

    # Restrain both dataframes to the target datetimes
    upper_htr = upper_htr[upper_htr.index.isin(datetimes)]
    lower_htr = lower_htr[lower_htr.index.isin(datetimes)]
    print(upper_htr) # TODO: it is missing columns. Check why, and how we can avoid it from breaking the automation part at the bottom of the nb !!
    print(lower_htr)
else:
    upper_htr = pd.DataFrame()  # Empty DataFrame if htr data is not to be shown
    lower_htr = pd.DataFrame()  # Empty DataFrame if htr data is not to be shown
# Out:
#                             _value  DeltaT   _field  actuator_instance board_id content  filling_density geo_loc hive_num inhive_loc          mcu_uuid          phys_loc  rpi_num   serial_id    valid
# _time
# 2025-07-23 19:00:00+00:00  30.80469   0.0   avg_temp         h06         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00   0.00000   0.0        obj         h06         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00   0.00000   0.0        pwm         h06         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00   0.00000   0.0     status         h06         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00  30.41406   0.0   avg_temp         h07         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# ...                             ...    ...       ...               ...      ...      ...             ...     ...      ...        ...                        ...      ...      ...           ...    ...
# 2025-07-26 19:00:00+00:00   0.00000   0.0     status         h09         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# 2025-07-26 19:00:00+00:00   0.00000   0.0        pwm         h09         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# 2025-07-26 19:00:00+00:00   0.00000   1.0     status         h00         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# 2025-07-26 19:00:00+00:00   0.00000   0.0        pwm         h01         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
# 2025-07-26 19:00:00+00:00   0.00000   0.0        obj         h01         abc03   Unknown      Unknown      EPFL      1       upper    2191217016663093217343026   bass       1     /dev/ttyACM0  True
#
# [37852 rows x 15 columns]
#                             _value  DeltaT   _field  actuator_instance board_id content  filling_density geo_loc hive_num inhive_loc          mcu_uuid          phys_loc  rpi_num   serial_id    valid
# _time
# 2025-07-23 19:00:00+00:00  31.71094   0.0   avg_temp         h00         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00  30.51563   0.0   avg_temp         h01         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00   0.00000   0.0        obj         h01         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00   0.00000   0.0     status         h01         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-23 19:00:00+00:00   0.00000   0.0        pwm         h01         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# ...                             ...    ...       ...               ...      ...      ...             ...     ...      ...        ...                        ...      ...      ...           ...    ...
# 2025-07-26 19:00:00+00:00   0.00000   0.0        pwm         h01         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-26 19:00:00+00:00   0.00000   3.0     status         h00         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-26 19:00:00+00:00   0.00000   3.0        pwm         h00         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-26 19:00:00+00:00   0.00000   3.0        obj         h00         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
# 2025-07-26 19:00:00+00:00  30.41406   3.0   avg_temp         h00         abc02   Unknown      Unknown      EPFL      1       lower    2191218169584597824190002   bass       2     /dev/ttyACM0  True
#
# [38096 rows x 15 columns]

# %% [markdown]
# ### Frame generation

# %%
def generate_frame(dt:pd.Timestamp, contours:list = []):
    """Generate a single annotated frame for the given datetime.

    Args:
        dt (pd.Timestamp): The datetime for which to generate the frame.
    Returns:
        np.ndarray: The generated annotated frame as an image array.
    """

    # Fetch the corresponding image paths
    _imgs_paths = imgs_paths.loc[dt].to_numpy()
    imgs_names = [str(_imgs_paths[j]).split("/")[-1][:-4] for j in range(len(_imgs_paths))]
    # Read the images using cv2
    current_imgs = []
    for _img_path in _imgs_paths:
        if _img_path is not None:
            img = cv2.imread(_img_path, cv2.IMREAD_GRAYSCALE)
            current_imgs.append(img)
        else:
            current_imgs.append(None)
    
    # Thermal data
    try:
        upper_tf = ThermalFrame(upper.loc[dt].to_numpy())
    except (NoValidSensors, KeyError):
        upper_tf = None

    try:
        lower_tf = ThermalFrame(lower.loc[dt].to_numpy())
    except (NoValidSensors, KeyError):
        lower_tf = None

    # Metabolic data
    if dt in co2_data.index:
        metabolic_df = co2_data.loc[dt]
    else:
        metabolic_df = None

    # Lower heater
    if dt in lower_htr.index:
        lower_htr_row = lower_htr.loc[dt]
    else:
        lower_htr_row = None

    # Upper heater
    if dt in upper_htr.index:
        upper_htr_row = upper_htr.loc[dt]
    else:
        upper_htr_row = None
    
    hs = Hive(dt, current_imgs, False, imgs_names, upper_tf, lower_tf, metabolic_df, upper_htr_row, lower_htr_row, hive_nb=hive_nb)
    if thermal_shift is not None:
        from libvisu import thermal_shifts
        hs.setThermalShifts(thermal_shifts[thermal_shift][hive_nb])
    snapshot = hs.snapshot(v_max=max_temp, v_min=min_temp, contours=contours, annotate_contours=True, show_htr_obj=False, thermal_transparency=0.4, check_validity=True, annotate_names=False, use_cet_time=True)

    return snapshot

# %% [markdown]
# ### Plotting

# %%
frame = 0 # Frame idx within datetimes
dt = datetimes[frame]
contours = list(range(12, 38, 2))
snapshot = generate_frame(dt, contours=contours)
# For a random time frame, generate the image of the hive and the thermal plot side by side with matplotlib
# This is just to check that everything is working fine
plt.figure(figsize=(18, 12))
plt.imshow(snapshot)
plt.axis('off') 
plt.show()

# %% [markdown]
# ### Automation

# %%
snapshot_0 = generate_frame(datetimes[0], contours=contours)
filename=f"hive{hive_nb}_{first_dt.strftime('%y%m%d-%H%M%Z')}_{last_dt.strftime('%y%m%d-%H%M%Z')}"
# If file exists, add a number to the name
counter = 1
while os.path.isfile(dest+filename+".mp4"):
    print(f"File {filename} already exists. Adding a counter to the filename.")
    if counter > 1:
        # Remove the previous counter
        filename = filename[:-(len(str(counter-1))+1)]
    filename = f"{filename}_{counter}"
    counter += 1
    
video = initVideoWriter(dest=dest, shape=snapshot_0.shape, name=filename, fps=fps) # RGB video
print("Writing video with dimensions: ", snapshot_0.shape)

for dt in tqdm(datetimes, desc="Generating video frames"):
    snapshot = generate_frame(dt, contours=contours)
    # Convert from RGB to BGR
    snapshot = cv2.cvtColor(snapshot, cv2.COLOR_RGB2BGR)
    video.write(snapshot)

# Release the VideoWriter object
video.release()
print("Video written successfully.")

# Cleanup step to release resources
multiprocessing.active_children()
# Out:
# Writing video with dimensions:  (2160, 3840, 3)
# Generating video frames:  95%|█████████▌| 822/865 [20:21<01:17,  1.80s/it]ERROR:tornado.application:Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 105 memory: 1601 MB fds: 186>>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
# Generating video frames: 100%|██████████| 865/865 [21:39<00:00,  1.50s/it]
# Video written successfully.
# [<SpawnProcess name='Dask Worker process (from Nanny)' pid=25689 parent=25673 started daemon>,
#  <SpawnProcess name='Dask Worker process (from Nanny)' pid=25691 parent=25673 started daemon>,
#  <SpawnProcess name='Dask Worker process (from Nanny)' pid=25690 parent=25673 started daemon>,
#  <SpawnProcess name='Dask Worker process (from Nanny)' pid=25692 parent=25673 started daemon>]
# 2026-02-04 17:31:33,047 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 2 memory: 34 MB fds: 25>>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
# 2026-02-04 17:41:45,050 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 2 memory: 36 MB fds: 25>>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
# 2026-02-04 17:55:46,041 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 2 memory: 32 MB fds: 25>>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/imaging/lib/python3.11/site-packages/psutil/__init__.py", line 2139, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
